# %% [markdown]
# # <center> <b> Fertilizante y Compost

# %% [markdown]
# <center>Evaluación de los efectos de la aplicación de fertilizantes orgánicos

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Registros

# %%
registros=pd.read_csv('Registros.csv')
registros
# Out:
#     Parcela   Compost [t/ ha]  N inorg. [kg/ ha]
# 0          1                0                173
# 1          2                0                166
# 2          3                0                155
# 3          4                6                164
# 4          5                6                188
# 5          6                6                177
# 6          7               12                170
# 7          8               12                185
# 8          9               12                198
# 9         10               18                200
# 10        11               18                192
# 11        12               18                206

# %% [markdown]
# ### Analisis de Regresión Lineal

# %%
Datos=pd.read_csv('Calculos.csv')
Datos
# Out:
#                 i    xi          yi  (xi-x raya)   (yi-y raya)  \
# 0               1   0.0  173.000000         -9.0 -8.166667e+00
# 1               2   0.0  166.000000         -9.0 -1.516667e+01
# 2               3   0.0  155.000000         -9.0 -2.616667e+01
# 3               4   6.0  164.000000         -3.0 -1.716667e+01
# 4               5   6.0  188.000000         -3.0  6.833333e+00
# 5               6   6.0  177.000000         -3.0 -4.166667e+00
# 6               7  12.0  170.000000          3.0 -1.116667e+01
# 7               8  12.0  185.000000          3.0  3.833333e+00
# 8               9  12.0  198.000000          3.0  1.683333e+01
# 9              10  18.0  200.000000          9.0  1.883333e+01
# 10             11  18.0  192.000000          9.0  1.083333e+01
# 11             12  18.0  206.000000          9.0  2.483333e+01
# 12            NaN   NaN         NaN          NaN           NaN
# 13   raya (media)   9.0  181.166667          0.0  1.136870e-13
#
# ...

# %% [markdown]
# ### Modelo de regresión lineal simple
# Relación entre (y) N inorgánico y (x) Dosis de Compost

# %%
points=pd.read_csv("DatosRegresion.csv")
sns.regplot(x="Dosis de compost", y="N inorgánico", data=points)
x_values=df['xi']
y_values=df['yi']
corr_matrix = np.corrcoef(x_values, y_values)
corr = corr_matrix[0,1]
R_sq = corr**2

# %%
print("R=",R_sq)
# Out:
# R= 0.6598246639392169
